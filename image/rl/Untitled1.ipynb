# %%
import numpy as np
import os

# %%
with open('laptop_6_1_0.out', 'r') as file:
    data = file.read().replace(' ','').replace('|','').split('\n')
data = [line for line in data if 'ep_rew_mean' in line]
data = [line.replace('ep_rew_mean','') for line in data]
data = [float(line) for line in data]
print(data)
# Out:
# [-148.0, -147.0, -158.0, -148.0, -146.0, -143.0, -137.0, -137.0, -135.0, -131.0, -131.0, -128.0, -126.0, -125.0, -123.0, -123.0, -123.0, -122.0, -123.0, -124.0, -124.0, -123.0, -123.0, -123.0, -124.0, -123.0, -122.0, -121.0, -120.0, -119.0, -118.0, -119.0, -119.0, -121.0, -123.0, -125.0, -126.0, -126.0, -126.0, -128.0, -127.0, -125.0, -125.0, -123.0, -121.0, -120.0, -118.0, -117.0, -116.0, -114.0, -114.0, -114.0, -112.0, -113.0, -113.0, -113.0, -112.0, -110.0, -107.0, -104.0, -101.0, -98.7, -97.5, -96.4, -93.9, -92.9, -92.4, -91.5, -90.7, -91.3, -90.1, -90.0, -89.2, -89.4, -88.4, -88.9, -87.4, -86.8, -85.1, -83.5, -82.1, -80.2, -78.4, -76.7, -75.0, -73.4, -72.3, -72.1, -69.7, -69.0, -67.6, -66.4, -64.7, -63.6, -61.4, -61.7, -61.3, -59.8, -58.0, -57.2, -53.5, -53.1, -51.9, -51.6, -50.7, -50.3, -51.3, -52.3, -54.3, -55.7, -55.9, -55.4, -56.1, -56.8, -57.0, -58.7, -59.2, -59.6, -59.5, -59.5, -58.9, -58.3, -58.9, -59.9, -58.3, -58.7, -58.2, -57.5, -56.7, -57.2, -56.8, -55.6, -53.8, -51.7
# ...

# %%
from matplotlib import pyplot as plt

# %%
print(len(data))
# Out:
# 1250

# %%
plt.plot(range(0,int(1e6),800),data)
plt.xlabel('timestep')
plt.ylabel('reward')
# Out:
# Text(0, 0.5, 'reward')
